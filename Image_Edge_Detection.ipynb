# %%
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
import numpy as np
from scipy import ndimage
from numpy import random
from astropy.visualization import make_lupton_rgb

# %%
img = cv2.imread('lane_detect_test.jpg',0)

# %% [markdown]
# # Canny Edge Detector

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=960x540 at 0x7F32011B4EF0>

# %%
edges = cv2.Canny(img,100,200)
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
img = cv2.imread('shapessm.jpg',0)
cv2_imshow(img)
edges = cv2.Canny(img,100,200)
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# <PIL.Image.Image image mode=L size=301x263 at 0x7F31FF951B70>

# %%
img = cv2.imread('step2line.png',0)
cv2_imshow(img)
edges = cv2.Canny(img,50,100)
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# <PIL.Image.Image image mode=L size=1188x565 at 0x7F31FCFF3CC0>

# %% [markdown]
# # Sobel

# %%
img = cv2.imread('lane_detect_test.jpg',0)

laplacian = cv2.Laplacian(img,cv2.CV_64F)
sobelx = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)
sobely = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=5)

plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(laplacian,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
img = cv2.imread('shapessm.jpg',0)

laplacian = cv2.Laplacian(img,cv2.CV_64F)
sobelx = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)
sobely = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=5)

plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(laplacian,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
img = cv2.imread('step2line.png',0)

laplacian = cv2.Laplacian(img,cv2.CV_64F)
sobelx = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)
sobely = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=5)

plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(laplacian,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])

plt.show()

# %% [markdown]
# # Hough transform

# %%
img = cv2.imread('lane_detect_test.jpg')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(gray,50,150,apertureSize = 3)

lines = cv2.HoughLines(edges,1,np.pi/180,200)
print(lines.shape)
print(lines)
for rho,theta in lines:
    a = np.cos(theta)
    b = np.sin(theta)
    x0 = a*rho
    y0 = b*rho
    x1 = int(x0 + 1000*(-b))
    y1 = int(y0 + 1000*(a))
    x2 = int(x0 - 1000*(-b))
    y2 = int(y0 - 1000*(a))

    cv2.line(img,(x1,y1),(x2,y2),(0,0,255),2)

cv2_imshow(img)
# Out:
# (8, 1, 2)
# [[[  5.          2.1293018]]
#
#  [[ -3.          2.146755 ]]
#
#  [[210.          1.7627826]]
#
#  [[347.          1.4835298]]
#
#  [[384.          1.3962634]]
#
#  [[325.          1.5184364]]
#
#  [[190.          1.7976891]]
#
#  [[329.          1.5184364]]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-d1e3a4d40620> in <module>()
#       6 print(lines.shape)
#       7 print(lines)
# ----> 8 for rho,theta in lines:
#       9     a = np.cos(theta)
#      10     b = np.sin(theta)
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
img = cv2.imread('/content/shapessm.jpg',0)
edges = cv2.Canny(img,50,150,apertureSize = 3)
cv2_imshow(edges)
lines = cv2.HoughLines(edges,1,np.pi/180,200)
for rho,theta in lines[0]:
    a = np.cos(theta)
    b = np.sin(theta)
    x0 = a*rho
    y0 = b*rho
    x1 = int(x0 + 1000*(-b))
    y1 = int(y0 + 1000*(a))
    x2 = int(x0 - 1000*(-b))
    y2 = int(y0 - 1000*(a))

    cv2.line(img,(x1,y1),(x2,y2),(0,0,255),2)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=301x263 at 0x7F31FD010BA8>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-93ec5c1fe164> in <module>()
#       3 cv2_imshow(edges)
#       4 lines = cv2.HoughLines(edges,1,np.pi/180,200)
# ----> 5 for rho,theta in lines[0]:
#       6     a = np.cos(theta)
#       7     b = np.sin(theta)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
img = cv2.imread('/content/step3line.pmg',0)
edges = cv2.Canny(img,50,150,apertureSize = 3)
lines = cv2.HoughLines(edges,1,np.pi/180,200)
for rho,theta in lines[0]:
    a = np.cos(theta)
    b = np.sin(theta)
    x0 = a*rho
    y0 = b*rho
    x1 = int(x0 + 1000*(-b))
    y1 = int(y0 + 1000*(a))
    x2 = int(x0 - 1000*(-b))
    y2 = int(y0 - 1000*(a))

    cv2.line(img,(x1,y1),(x2,y2),(0,0,255),2)

cv2_imshow(img)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-29af4e4b692e> in <module>()
#       2 edges = cv2.Canny(img,50,150,apertureSize = 3)
#       3 lines = cv2.HoughLines(edges,1,np.pi/180,200)
# ----> 4 for rho,theta in lines[0]:
#       5     a = np.cos(theta)
#       6     b = np.sin(theta)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
img = cv2.imread('/content/11381546964_d88dbf476f_b.jpg',0)
edges = cv2.Canny(img,50,150,apertureSize = 3)
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=1023x1022 at 0x7F31FCFEBC18>
