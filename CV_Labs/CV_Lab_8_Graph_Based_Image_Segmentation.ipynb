# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('messi.jpg')
mask = np.zeros(img.shape[:2],np.uint8)
print(img.shape)
print(mask.shape)
# Out:
# (401, 632, 3)
# (401, 632)

# %%
bgdModel = np.zeros((1,65),np.float64)
fgdModel = np.zeros((1,65),np.float64)
bgdModel.shape, fgdModel.shape
# Out:
# ((1, 65), (1, 65))

# %%
plt.imshow(img)

# %%
rect = (50,50,450,350)
#rect = (20,20,600,600)
#image = cv2.rectangle(img, (50,50), (600,600), color = (255, 0, 0) , thickness =2) 
#cv2_imshow(image)

# %%
cv2.grabCut(img,mask,rect,bgdModel,fgdModel,5,cv2.GC_INIT_WITH_RECT)
mask2 = np.where((mask==2)|(mask==0),0,1).astype('uint8')
mask2.shape
# Out:
# (401, 632)

# %%
img = img*mask2[:,:,np.newaxis]
img.shape
# Out:
# (401, 632, 3)

# %%
plt.imshow(img),plt.colorbar(),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7f0e4c5a1320>,
#  <matplotlib.colorbar.Colorbar at 0x7f0e4c553d30>,
#  None)
